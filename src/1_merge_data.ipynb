# %%
import pandas as pd
from pathlib import Path

from s1_data_processing.merge_data import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
counts = merge_data(path_to_data = "../../data/htseq_counts_2/", 
           saved_path="../../data/mg_counts_2203.tsv", is_counts=True)

# %%
tpms = merge_data(path_to_data = "../../data/TPM_2/", 
           saved_path="../../data/mg_tpm_2203.tsv", is_counts=False)

# %%
rle = cal_rle(counts)
# Out:
# C:\Users\user\Anaconda3\envs\CBM\lib\site-packages\scipy\stats\stats.py:402: RuntimeWarning: divide by zero encountered in log
#   log_a = np.log(np.array(a, dtype=dtype))

# %%
rle.to_csv("../../data/mg_RLE.tsv", sep='\t')

# %%
label = pd.read_excel("../../data/all_info/labels.xlsx", sheet_name="2022march")
label.to_csv("../../data/all_info/labels.csv", sep='\t', index=False)

# %%
label
# Out:
#    sample sex extraction date(not all)  group        age   seq date  batch  \
# 0    R001   M               2019-07-09      4  31.536986 2019-11-08    1.0
# 1    R002   F               2019-08-08      2  42.301370 2019-11-08    1.0
# 2    R003   F               2019-08-29      2  42.358904 2019-11-08    1.0
# 3    R004   M               2019-08-30      3  23.863014 2019-11-08    1.0
# 4    R005   M               2019-09-05      2  15.369863 2019-11-08    1.0
# ..    ...  ..                      ...    ...        ...        ...    ...
# 61   C008   M                      NaT      1  27.778082 2019-11-08    1.0
# 62   C009   M                      NaT      1  32.035616 2019-11-08    1.0
# 63   C010   M                      NaT      1  31.778082 2019-11-08    1.0
# 64   C011   M                      NaT      1  24.287671 2020-08-14    3.0
# 65   C012   M                      NaT      1  26.142466 2020-08-14    3.0
#
#                      disease  subgroup
# 0   abnormal immune function       inf
# 1                  mt3243A>G     melas
# 2                  mt3243A>G     melas
# 3                        NaN     other
# 4             Large deletion  nonmelas
# ..                       ...       ...
# 61                       NaN   control
# 62                       NaN   control
# 63                       NaN   control
# 64                       NaN   control
# 65                       NaN   control
#
# [66 rows x 9 columns]

# %%
order = label.sort_values("subgroup")["sample"]

# %%
mp.loc[[i+"A" for i in order], [i+"A" for i in order]]
# Out:
#           R026A     R014A     R022A     R018A     R031A     R043A     C011A  \
# R026A  1.000000  0.974909  0.975794  0.974942  0.949628  0.973938  0.968077
# R014A  0.974909  1.000000  0.984199  0.980051  0.960620  0.977159  0.976567
# R022A  0.975794  0.984199  1.000000  0.982106  0.960562  0.978253  0.977615
# R018A  0.974942  0.980051  0.982106  1.000000  0.958496  0.984503  0.986904
# R031A  0.949628  0.960620  0.960562  0.958496  1.000000  0.942632  0.958337
# ...         ...       ...       ...       ...       ...       ...       ...
# R040A  0.969709  0.978487  0.975596  0.978853  0.948931  0.981270  0.975067
# R012A  0.971616  0.971416  0.975719  0.975791  0.950359  0.977601  0.975496
# R054A  0.966299  0.974223  0.971928  0.969839  0.938429  0.976531  0.966024
# R016A  0.974616  0.982447  0.982319  0.983954  0.962588  0.979732  0.984130
# R033A  0.966642  0.975425  0.978836  0.980467  0.957866  0.976790  0.982443
#
#           R035A     C012A     C004A  ...     R048A     R030A     R034A  \
# R026A  0.949654  0.963821  0.967191  ...  0.972864  0.971902  0.967657
# R014A  0.955387  0.970411  0.978970  ...  0.977613  0.976448  0.968650
# R022A  0.956489  0.972903  0.981132  ...  0.979135  0.979332  0.969605
# R018A  0.969729  0.984327  0.984227  ...  0.982510  0.984299  0.969490
# R031A  0.940857  0.953333  0.963692  ...  0.939684  0.963266  0.965114
# ...         ...       ...       ...  ...       ...       ...       ...
# R040A  0.956272  0.969761  0.975093  ...  0.982528  0.970345  0.967518
# R012A  0.963046  0.971280  0.978734  ...  0.975816  0.972352  0.968844
# R054A  0.952170  0.961968  0.972384  ...  0.980154  0.958587  0.964226
# R016A  0.969585  0.981235  0.983822  ...  0.978545  0.982185  0.968916
# R033A  0.975195  0.981281  0.984326  ...  0.976653  0.979303  0.966953
#
#           R057A     R013A     R040A     R012A     R054A     R016A     R033A
# R026A  0.943862  0.968249  0.969709  0.971616  0.966299  0.974616  0.966642
# R014A  0.955159  0.980220  0.978487  0.971416  0.974223  0.982447  0.975425
# R022A  0.951358  0.978801  0.975596  0.975719  0.971928  0.982319  0.978836
# R018A  0.959050  0.978059  0.978853  0.975791  0.969839  0.983954  0.980467
# R031A  0.924884  0.951632  0.948931  0.950359  0.938429  0.962588  0.957866
# ...         ...       ...       ...       ...       ...       ...       ...
# R040A  0.961895  0.973843  1.000000  0.969091  0.972370  0.974767  0.968532
# R012A  0.954954  0.976926  0.969091  1.000000  0.969600  0.977863  0.980413
# R054A  0.963874  0.978515  0.972370  0.969600  1.000000  0.969592  0.968326
# R016A  0.957375  0.980857  0.974767  0.977863  0.969592  1.000000  0.983862
# R033A  0.956772  0.981072  0.968532  0.980413  0.968326  0.983862  1.000000
#
# [66 rows x 66 columns]

# %%
label.sort_values("subgroup")["subgroup"].to_list()
# Out:
# ['bone',
#  'bone',
#  'cns',
#  'cns',
#  'cns',
#  'cns',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'control',
#  'inf',
#  'inf',
#  'inf',
#  'melas',
#  'melas',
#  'melas',
#  'melas',
#  'melas',
#  'melas',
#  'melas',
#  'melas',
#  'melas',
#  'melas',
#  'melas',
#  'melas',
#  'met',
#  'met',
#  'met',
#  'met',
#  'met',
#  'met',
#  'met',
#  'met',
#  'met',
#  'met',
#  'met',
#  'met',
#  'met',
#  'nonmelas',
#  'nonmelas',
#  'nonmelas',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other']

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(mp.loc[[i+"A" for i in order], [i+"A" for i in order]])
# Out:
# <AxesSubplot:>
